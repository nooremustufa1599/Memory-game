# %%
import time
import threading
from tkinter import *
import random 
import os
from PIL import Image,ImageTk
from tkinter import messagebox

# %%
class gameclass(Tk):
    def_init(game)
    super()._init_()
    game.geometry("850x600")
    game.config(bg="Black")
    game.number=0
    game.number_list=[]
    game.random_character=""
    
def Label(game):
    game.Label1=Label(game,text="",font=("times",30)(bg='black'))
    game.Label1.place(x=274,y=450)
game.random_character_Label=Label(game,text="",font=("times",30),bg='Black')
game.label1.place(x=274,y=450)

game.button1=Button(game,image="",command=lambda:game.check(1),borderwidth=1,height=5,widhth=17)
game.button1.place(x=280,y=20)

game.button2=Button(game,image="",command=lambda:game.check(2),borderwidth=1,height=5,widhth=17)
game.button2.place(x=450,y=20)

game.button3=Button(game,image="",command=lambda:game.check(3),borderwidth=1,height=5,widhth=17)
game.button3.place(x=630,y=20)

game.button4=Button(game,image="",command=lambda:game.check(4),borderwidth=1,height=5,widhth=17)
game.button4.place(x=280,y=150)

game.button5=Button(game,image="",command=lambda:game.check(5),borderwidth=1,height=5,widhth=17)
game.button5.place(x=450,y=150)

game.button6=Button(game,image="",command=lambda:game.check(6),borderwidth=1,height=5,widhth=17)
game.button6.place(x=630,y=150)

game.button7=Button(game,image="",command=lambda:game.check(7),borderwidth=1,height=5,widhth=17)
game.button7.place(x=280,y=280)

game.button8=Button(game,image="",command=lambda:game.check(8),borderwidth=1,height=5,widhth=17)
game.button8.place(x=450,y=280)

game.button9=Button(game,image="",command=lambda:game.check(9),borderwidth=1,height=5,widhth=17)
game.button9.place(x=630,y=280)

game.showbutton=Button(game,text="show",command=game.start_shuffle,borderwidth=0,height=5,width=17)
game.showbutton.place(x=40,y=150)
    
def start_shuffle(game):
    #game.number_list=[]
    if (game.number% 2)==0:
        game.number_list = os.listdir('.')
        game.number_list.remove("1.py")  
        game.number_list.remove("blank.png")
        random.shuffle(game.number_list)
game.img1=ImageTk.photoImage(Image.open(game.number_list[0]))
game.button1=Button(game,image=game.img1,Command=lambda:game.check(1))
game.button1.place(x=280,y=20)
#button1.config(image=img)
game.img2=ImageTk.photoImage(Image.open(game.number_list[1]))
game.button2=Button(game,image=game.img2,command=lambda:game.check(2))
game.button2.place(x=450,y=20)
#button2.config(text=number_list[1])
game.img3=ImageTk.photoImage(Image.open(game.number_list[2]))
game.button3=Button(game,image=game.img3,command=lambda:game.check(3))
game.button3.place(x=630,y=20)

game.img4=ImageTk.photoImage(Image.open(game.number_list[3]))
game.button4=Button(game,image=game.img1,command=lambda:game.check(4))
game.button4.place(x=280,y=150)

game.img5=ImageTk.photoImage(Image.open(game.number_list[4]))
game.button5=Button(game,image=game.img5,command=lambda:game.check(5))
game.button5.place(x=450,y=150)
#button1.config(image=img)
game.img6=ImageTk.photoImage(Image.open(game.number_list[5]))
game.button6=Button(game,image=game.img6,command=lambda:game.check(6))
game.button.place(x=630,y=150)
#button2.config(text=number_list[1])
game.img7=ImageTk.photoImage(Image.open(game.number_list[6]))
game.button7=Button(game,image=game.img7,command=lambda:game.check(7))
game.button7.place(x=280,y=280)

game.img8=ImageTk.photoImage(Image.open(game.number_list[7]))
game.button8=Button(game,image=game.img8,command=lambda:game.check(8))
game.button8.place(x=450,y=280)

game.img9=ImageTk.photoImage(Image.open(game.number_list[8]))
game.button9=Button(game,image=game.img9,command=lambda:game.check(9))
game.button9.place(x=630,y=280)
game.showbutton.config(text="Hide")
game.number=game.number+1
game.Label1.destroy()
game.random_character_Label.destroy()
#print(jkb)
#print(game.number_list)
#return game.number_list,game.number
return game.number

  else:
    
    game.number_list.remove("1.py")
    game.random_character=random.choice(game.number_list)
     #print(game.random_character)
     #print(game.number_list)
    
game.imgbtn=ImageTk.photoImage(Image.open("blank.png"))
game.showbutton.config(text="Show")
game.button1.config(image=game.imgbtn)
game.button2.config(image=game.imgbtn)
game.button3.config(image=game.imgbtn)
game.button4.config(image=game.imgbtn)
game.button5.config(image=game.imgbtn)
game.button6.config(image=game.imgbtn)
game.button7.config(image=game.imgbtn)
game.button8.config(image=game.imgbtn)
game.button9.config(image=game.imgbtn)
game.Label1=Label(game,text="Doraemon",font=("times",30),bg='black')
game.Label1.place(x=274,y=450)

game.random_character_label_image=ImageTk.PhotoImage(Image.open(game.random_character))
game.random_character_label=label(game,image=game.random_character_label_image)
game.random_character_label.place(x=510,y=440)
#number list=[]
game.number=game.number+1
#print(number_list,number)
#return game.number_list,game.number

 def check(game,btnnumbr):
    if game.number_list==[]:
        messagebox.showinfo("Memory Game","Let's start the Game first")
            return
        
        elif game.random_character=="":
            messagebox.showinfo("Memory Game","let's start the Game first")
        
    #print(game.number_list)
    #print(game.random_character)
    
        elif btnnmbr==1:
        if game.number_list[0]==game.random_character:
        messagebox.showinfo("Memory Game","Correct Choice")
        elif btnnmbr==2:
        if game.number_list[1]==game.random_character:
        messagebox.showinfo("Memory Game","Correct Choice")
        elif btnnmbr==3:
        if game.number_list[2]==game.random_character:
        messagebox.showinfo("Memory Game","Correct Choice")
        elif btnnmbr==4:
        if game.number_list[3]==game.random_character:
        messagebox.showinfo("Memory Game","Correct Choice")
        elif btnnmbr==5:
        if game.number_list[4]==game.random_character:
        messagebox.showinfo("Memory Game","Correct Choice")
        elif btnnmbr==6:
        if game.number_list[5]==game.random_character:
            messagebox.showinfo("Memory Game","Correct Choice")
        elif btnnmbr==7:
        if game.number_list[6]==game.random_character:
            messagebox.showinfo("Memory Game","Correct Choice")
        elif btnnmbr==8:
        if game.number_list[7]==game.random_character:
            messagebox.showinfo("Memory Game","Correct Choice")
        elif btnnmbr==9: 
        if game.number_list[8]==game.random_character:
            messagebox.showinfo("Memory Game","Correct Choice")
        
if_name_=="_main_":
    Game=gameclass()
    Game.Label()
    Game.mainloop()
# Out:
#   Input In [5]
#     else:
#     ^
# IndentationError: unexpected indent
